# %% [markdown]
# # **Problem statement:**
# Create a dataframe with title, cause, action for the Oracle Errors by extracting information from a given website and save it to csv for further use.
#
# ---
#
#
#
# ---

# %% [markdown]
# Import Libraries

# %%
from bs4 import BeautifulSoup
import urllib
import pandas as pd

# %% [markdown]
# urllib.request helps to open URL

# %%
# Give the URL of webpage of which you want extract data
url = "https://docs.oracle.com/cd/B28359_01/server.111/b28278/e900.htm#ORA-00910"    
html = urllib.request.urlopen(url).read()

# %% [markdown]
# Get html code using lxml parser

# %%
soup = BeautifulSoup(html , "lxml")    # lxml - parser   
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1" name="viewport"/>
#   <meta charset="utf-8"/>
#   <title>
#    ORA-00910 to ORA-01497
#   </title>
#   <meta content="Oracle DARB XHTML Converter (Mode = document) - Version 5.1 Build 125" name="generator"/>
#   <meta content="2008-11-24T14:48:31Z" name="dcterms.created"/>
#   <meta content="all" name="robots"/>
#   <meta content="Database Error Messages" name="dcterms.title"/>
#   <meta content="B28278-02" name="dcterms.identifier"/>
#   <meta content="ERRMG" name="dcterms.isVersionOf"/>
#   <link href="../../index.htm" rel="Start" title="Home" type="text/html"/>
#   <link href="../../dcommon/html/cpyr.htm" rel="Copyright" title="Copyright" type="text/html"/>
#   <script src="../../dcommon/js/headfoot.js" type="application/javascript">
#   </script>
#   <script src="../../nav/js/doccd.js" type="application/javascript">
#   </script>
#   <link href="toc.htm" rel="Contents" title="Contents" type="text/html"/>
#   <link href="index.htm" rel="Index" title="Index" type="text/html"/>
#   <link href="e0.htm" rel="Prev" title="Previous" type="text/html"/>
#   <link href="e1500.htm" rel="Next" title="Next" type="text/html"/>
#   <link href="../B28278-02.epub" rel="alternate" title="ePub version" type="application/epub+zip"/>
#   <link href="../B28278-02.mobi" rel="alternate" title="Mobipocket version" type="application/x-mobipocket-ebook"/>
#   <link href="http://purl.org/dc/terms/" rel="schema.dcterms"/>
#   <link href="../../dcommon/css/fusiondoc.css" rel="stylesheet"/>
#   <link href="../../dcommon/css/header.css" rel="stylesheet" type="text/css"/>
#   <link href="../../dcommon/css/footer.css" rel="stylesheet" type="text/css"/>
#   <link href="../../dcommon/css/fonts.css" rel="stylesheet" type="text/css"/>
#   <link href="../../dcommon/css/foundation.css" rel="stylesheet"/>
#   <link href="../../dcommon/css/codemirror.css" rel="stylesheet"/>
#   <link href="../../nav/css/html5.css" rel="stylesheet" title="Default" type="text/css"/>
#   <link href="../../dcommon/css/respond-480-tablet.css" rel="stylesheet"/>
#   <link href="../../dcommon/css/respond-768-laptop.css" rel="stylesheet"/>
#   <link href="../../dcommon/css/respond-1140-deskop.css" rel="stylesheet"/>
#   <script src="../../dcommon/js/modernizr.js" type="application/javascript">
#   </script>
#   <script src="../../dcommon/js/codemirror.js" type="application/javascript">
#   </script>
#   <script src="../../dcommon/js/jquery.js" type="application/javascript">
#   </script>
#   <script src="../../dcommon/js/foundation.min.js" type="application/javascript">
#   </script>
#   <script async="async" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-552992c80ef99c8d" type="text/javascript">
#   </script>
#   <script src="../../dcommon/js/jqfns.js" type="application/javascript">
#   </script>
#   <script src="../../dcommon/js/ohc-inline-videos.js" type="application/javascript">
#   </script>
#   <!-- Add fancyBox -->
#   <link href="../../dcommon/fancybox/jquery.fancybox.css?v=2.1.5" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="../../dcommon/fancybox/jquery.fancybox.pack.js?v=2.1.5" type="text/javascript">
#   </script>
#   <!-- Optionally add helpers - button, thumbnail and/or media -->
#   <link href="../../dcommon/fancybox/helpers/jquery.fancybox-buttons.css?v=1.0.5" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="../../dcommon/fancybox/helpers/jquery.fancybox-buttons.js?v=1.0.5" type="text/javascript">
#   </script>
#   <script src="../../dcommon/fancybox/helpers/jquery.fancybox-media.js?v=1.0.6" type="text/javascript">
#   </script>
#   <link href="../../dcommon/fancybox/helpers/jquery.fancybox-thumbs.css?v=1.0.7" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="../../dcommon/fancybox/helpers/jquery.fancybox-thumbs.js?v=1.0.7" type="text/javascript">
#   </script>
#   <script>
#    window.ohcglobal || document.write('<script src="/en/dcommon/js/global.js">\x3C/script>')
#   </script>
#  </head>
#  <body>
#   <a class="accessibility-top skipto" href="#BEGIN" tabindex="0">
#    Go to main content
#   </a>
#   <header>
#    <!--
# <div class="zz-skip-header"><a id="top" href="#BEGIN">Go to main content</a>-->
#   </header>
#   <div class="row" id="CONTENT">
#    <div class="IND large-9 medium-8 columns">
#     <a id="BEGIN" name="BEGIN">
#     </a>
#     <span id="PAGE" style="display:none;">
#      6/86
#     </span>
#     <!-- End Header -->
#     <a id="sthref438">
#     </a>
#     <h1 class="chapter">
#      <span class="secnum">
#       3
#      </span>
#      ORA-00910 to ORA-01497
#     </h1>
#     <div class="msgset">
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref439">
#          </a>
#          <a id="ORA-00910">
#          </a>
#          ORA-00910: specified length too long for its datatype
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          for datatypes CHAR and RAW, the length specified was &gt; 2000; otherwise, the length specified was &gt; 4000.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          use a shorter length or switch to a datatype permitting a longer length such as a VARCHAR2, LONG CHAR, or LONG RAW
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref440">
#          </a>
#          <a id="ORA-00911">
#          </a>
#          ORA-00911: invalid character
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          identifiers may not start with any ASCII character other than letters and numbers. $#_ are also allowed after the first character. Identifiers enclosed by doublequotes may contain any character other than a doublequote. Alternative quotes (q'#...#') cannot use spaces, tabs, or carriage returns as delimiters. For all other contexts, consult the SQL Language Reference Manual.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          None
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref441">
#          </a>
#          <a id="ORA-00912">
#          </a>
#          ORA-00912: input parameter too long
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          one of your input strings was too long
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          shorten the input parameter length
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref442">
#          </a>
#          <a id="ORA-00953">
#          </a>
#          ORA-00953: missing or invalid index name
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An index name of the form [ &lt;identifier&gt; . ] &lt;identifier&gt; is expected but not present. If OIDINDEX clause, index name must be &lt;identifier&gt;
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Enter an appropriate index name.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref443">
#          </a>
#          <a id="ORA-00956">
#          </a>
#          ORA-00956: missing or invalid auditing option
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          AUDIT or NOAUDIT statement contains an invalid auditing option.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Use a valid option.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref444">
#          </a>
#          <a id="ORA-00960">
#          </a>
#          ORA-00960: ambiguous column naming in select list
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          A column name in the order-by list matches more than one select list columns.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Remove duplicate column naming in select list.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref445">
#          </a>
#          <a id="ORA-00962">
#          </a>
#          ORA-00962: too many group-by / order-by expressions
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The group-by or order-by column list contain more than 1000 expressions.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Use 1000 or less expressions in the group-by or order-by list.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref446">
#          </a>
#          <a id="ORA-00964">
#          </a>
#          ORA-00964: table name not in FROM list
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The table name referred in the select list is not specified in the from list.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Make sure the name is correctly specified and matches one of the names in the from list.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref447">
#          </a>
#          <a id="ORA-00965">
#          </a>
#          ORA-00965: column aliases not allowed for '*'
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The statement is trying to alias the * expression in the select list which is not legal.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Remove the alias.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref448">
#          </a>
#          <a id="ORA-00972">
#          </a>
#          ORA-00972: identifier is too long
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An identifier with more than 30 characters was specified.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Specify at most 30 characters.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref449">
#          </a>
#          <a id="ORA-00976">
#          </a>
#          ORA-00976: LEVEL, PRIOR, or ROWNUM not allowed here
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          LEVEL, PRIOR, or ROWNUM is being specified at illegal location.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Remove LEVEL, PRIOR, or ROWNUM.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref450">
#          </a>
#          <a id="ORA-00977">
#          </a>
#          ORA-00977: duplicate auditing option
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          AUDIT or NOAUDIT statement specifies an option more than once
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Either use ALL with no other auditing options or make sure no option is listed more than once.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref451">
#          </a>
#          <a id="ORA-00980">
#          </a>
#          ORA-00980: synonym translation is no longer valid
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          A synonym did not translate to a legal target object. This could happen for one of the following reasons:
#          <p>
#           1. The target schema does not exist.
#          </p>
#          <p>
#           2. The target object does not exist.
#          </p>
#          <p>
#           3. The synonym specifies an incorrect database link.
#          </p>
#          <p>
#           4. The synonym is not versioned but specifies a versioned target object.
#          </p>
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Change the synonym definition so that the synonym points at a legal target object.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref452">
#          </a>
#          <a id="ORA-00981">
#          </a>
#          ORA-00981: cannot mix table and system auditing options
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Table and system-wide auditing options were specified in the same AUDIT or NOAUDIT statement.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          You must issue table and system options in separate statements.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref453">
#          </a>
#          <a id="ORA-00983">
#          </a>
#          ORA-00983: cannot audit or noaudit SYS user actions
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An attempt was made to AUDIT or NOAUDIT SYS user actions.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Execute the statement again with a valid user.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref454">
#          </a>
#          <a id="ORA-00991">
#          </a>
#          ORA-00991: only MAC privileges may be granted to procedures
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Object privileges or non-MAC system privileges were granted to the procedure.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Only grant MAC privileges using the PROCEDURE clause.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref455">
#          </a>
#          <a id="ORA-01002">
#          </a>
#          ORA-01002: fetch out of sequence
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          This error means that a fetch has been attempted from a cursor which is no longer valid. Note that a PL/SQL cursor loop implicitly does fetches, and thus may also cause this error. There are a number of possible causes for this error, including: 1) Fetching from a cursor after the last row has been retrieved and the ORA-1403 error returned. 2) If the cursor has been opened with the FOR UPDATE clause, fetching after a COMMIT has been issued will return the error. 3) Rebinding any placeholders in the SQL statement, then issuing a fetch before reexecuting the statement.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          1) Do not issue a fetch statement after the last row has been retrieved - there are no more rows to fetch. 2) Do not issue a COMMIT inside a fetch loop for a cursor that has been opened FOR UPDATE. 3) Reexecute the statement after rebinding, then attempt to fetch again.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref456">
#          </a>
#          <a id="ORA-01010">
#          </a>
#          ORA-01010: invalid OCI operation
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          One of the following: 1) You attempted an invalid OCI operation. 2) You are using an Oracle client application linked with version 7.1 (or higher) libraries, the environment variable ORA_ENCRYPT_LOGIN is set to TRUE, and you attempted to connect to a version 7.0 (or lower) Oracle Server. 3) You are connected to a version 7.1 (or higher) Oracle Server, the initialization parameter DBLINK_ENCRYPT_LOGIN is set to TRUE, and you attempted to use a database link pointing to a version 7.0 (or lower) Oracle Server. 4) You are connected to a version 9.0.2(or higher) Oracle Server and you attempted to use a database link pointing to a version 9.0.1(or lower) Oracle Server for distributed autonomous transaction.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          For the above causes: 1) Do not use the invalid OCI operation. 2) If you do not wish to use encrypted connect passwords in your distributed database, set ORA_ENCRYPT_LOGIN to FALSE. If you wish to use encrypted connect passwords, you must upgrade all Oracle Servers to version 7.1 (or higher). 3) If you do not wish to use encrypted database links in your distributed database, set DBLINK_ENCRYPT_LOGIN to FALSE. If you wish to use encrypted database links, you must upgrade all Oracle Servers to version 7.1 (or higher). 4) Do not attempt distributed autonomous transaction on version 9.0.1(or lower) Oracle Server.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref457">
#          </a>
#          <a id="ORA-01016">
#          </a>
#          ORA-01016: This function can be called only after a fetch
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Cursor in an invalid state.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Make sure that the oci/upi function is called after fetch.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref458">
#          </a>
#          <a id="ORA-01019">
#          </a>
#          ORA-01019: unable to allocate memory in the user side
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The user side memory allocator returned error.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Increase the processes heap size or switch to the old set of calls.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref459">
#          </a>
#          <a id="ORA-01022">
#          </a>
#          ORA-01022: database operation not supported in this configuration
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The attempted database operation does not conform to the user programming interface (UPI) for the two communicating ORACLE servers.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          You may need to upgrade one or more of your ORACLE servers or re-link your user side application with new libraries. Report the problem to Worldwide Customer Support.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref460">
#          </a>
#          <a id="ORA-01023">
#          </a>
#          ORA-01023: Cursor context not found (Invalid cursor number)
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The cursor number is not a valid open cursor.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Make sure that the cursor is open.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref461">
#          </a>
#          <a id="ORA-01025">
#          </a>
#          ORA-01025: UPI parameter out of range
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An integer parameter to a upi function is out of range.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          This usually indicates an error in a tool built on top of the oracle dbms. Report the error to your customer support representative.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref462">
#          </a>
#          <a id="ORA-01026">
#          </a>
#          ORA-01026: multiple buffers of size &gt; 4000 in the bind list
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          More than one long buffer in the bind list.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Change the buffer size to be less than 4000 for the bind variable bound to a normal column.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref463">
#          </a>
#          <a id="ORA-01027">
#          </a>
#          ORA-01027: bind variables not allowed for data definition operations
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An attempt was made to use a bind variable in a SQL data definition operation.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Such bind variables are not allowed.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref464">
#          </a>
#          <a id="ORA-01028">
#          </a>
#          ORA-01028: internal two task error
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Received send long message but don't have the cursor context.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Report as a bug.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref465">
#          </a>
#          <a id="ORA-01029">
#          </a>
#          ORA-01029: internal two task error
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Received a request to send the long again when there is no long
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Report as a bug
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref466">
#          </a>
#          <a id="ORA-01030">
#          </a>
#          ORA-01030: SELECT ... INTO variable does not exist
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The SELECT... INTO specified in the bind call does not correspond to a variable in the SQL statement.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          If it is not possible to correct the statement, call customer support.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref467">
#          </a>
#          <a id="ORA-01031">
#          </a>
#          ORA-01031: insufficient privileges
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An attempt was made to change the current username or password without the appropriate privilege. This error also occurs if attempting to install a database without the necessary operating system privileges. When Trusted Oracle is configure in DBMS MAC, this error may occur if the user was granted the necessary privilege at a higher label than the current login.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Ask the database administrator to perform the operation or grant the required privileges. For Trusted Oracle users getting this error although granted the the appropriate privilege at a higher label, ask the database administrator to regrant the privilege at the appropriate label.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref468">
#          </a>
#          <a id="ORA-01032">
#          </a>
#          ORA-01032: no such userid
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          This is an internal error message related to Export/Import.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Contact customer support.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref469">
#          </a>
#          <a id="ORA-01033">
#          </a>
#          ORA-01033: ORACLE initialization or shutdown in progress
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An attempt was made to log on while Oracle is being started up or shutdown.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Wait a few minutes. Then retry the operation.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref470">
#          </a>
#          <a id="ORA-01034">
#          </a>
#          ORA-01034: ORACLE not available
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Oracle was not started up. Possible causes include the following:
#          <p>
#           - The SGA requires more space than was allocated for it.
#          </p>
#          <p>
#           - The operating-system variable pointing to the instance is improperly defined.
#          </p>
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Refer to accompanying messages for possible causes and correct the problem mentioned in the other messages. If Oracle has been initialized, then on some operating systems, verify that Oracle was linked correctly. See the platform specific Oracle documentation.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref471">
#          </a>
#          <a id="ORA-01035">
#          </a>
#          ORA-01035: ORACLE only available to users with RESTRICTED SESSION privilege
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Logins are disallowed because an instance started in restricted mode. Only users with RESTRICTED SESSION system privilege can log on.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Request that Oracle be restarted without the restricted option or obtain the RESTRICTED SESSION system privilege.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref472">
#          </a>
#          <a id="ORA-01036">
#          </a>
#          ORA-01036: illegal variable name/number
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Unable to find bind context on user side
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Make sure that the variable being bound is in the sql statement.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref473">
#          </a>
#          <a id="ORA-01037">
#          </a>
#          ORA-01037: maximum cursor memory exceeded
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Attempting to process a complex sql statement which consumed all available memory of the cursor.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Simplify the complex sql statement.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref474">
#          </a>
#          <a id="ORA-01038">
#          </a>
#          ORA-01038: cannot write database file version
#          <span class="italic">
#           string
#          </span>
#          with ORACLE version
#          <span class="italic">
#           string
#          </span>
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Attempting to write datafile headers in an old format. The new format can not be used until after the database has been verified as being compatible with this software version.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Open the database to advance to the new file formats, then repeat the operation. If the operation is required before the database can be opened, then use the previous software release to do the operation.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref475">
#          </a>
#          <a id="ORA-01039">
#          </a>
#          ORA-01039: insufficient privileges on underlying objects of the view
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Attempting to explain plan on other people's view without the necessary privileges on the underlying objects of the view.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Get necessary privileges or do not perform the offending operation.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref476">
#          </a>
#          <a id="ORA-01040">
#          </a>
#          ORA-01040: invalid character in password; logon denied
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          There are multibyte characters in the password or some characters in the password are not in US7ASCII range.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Resubmit password with valid characters.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref477">
#          </a>
#          <a id="ORA-01041">
#          </a>
#          ORA-01041: internal error. hostdef extension doesn't exist
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Pointer to hstdef extension in hstdef is null.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Report as a bug
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref478">
#          </a>
#          <a id="ORA-01042">
#          </a>
#          ORA-01042: detaching a session with open cursors not allowed
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An attempt was made to detach a seesio n which had open cursors.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Close all the cursors before detaching the session.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref479">
#          </a>
#          <a id="ORA-01043">
#          </a>
#          ORA-01043: user side memory corruption [
#          <span class="italic">
#           string
#          </span>
#          ], [
#          <span class="italic">
#           string
#          </span>
#          ], [
#          <span class="italic">
#           string
#          </span>
#          ], [
#          <span class="italic">
#           string
#          </span>
#          ]
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The application code corrupted some of the usr memory used by oracle
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Make sure that the application code is not overwriting memory.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref480">
#          </a>
#          <a id="ORA-01044">
#          </a>
#          ORA-01044: size
#          <span class="italic">
#           string
#          </span>
#          of buffer bound to variable exceeds maximum
#          <span class="italic">
#           string
#          </span>
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An attempt was made to bind a buffer whose total size would exceed the maximum size allowed. Total array size for arrays is calculated as: (element_size)*(number of elements)
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Reduce buffer size.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref481">
#          </a>
#          <a id="ORA-01045">
#          </a>
#          ORA-01045: user
#          <span class="italic">
#           string
#          </span>
#          lacks CREATE SESSION privilege; logon denied
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          A connect was attempted to a userid which does not have create session privilege.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Grant the user CREATE SESSION privilege.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref482">
#          </a>
#          <a id="ORA-01048">
#          </a>
#          ORA-01048: Couldn't find the specified procedure in the given context
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The procedure user specified in deferred RPC doesn't exist.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Check to make sure that the procedure exists and is visible to the replication process.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref483">
#          </a>
#          <a id="ORA-01049">
#          </a>
#          ORA-01049: Bind by name is not spupportted in streamed RPC
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          A newer version of server is talking with this version requesting an operation not supported in this version.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          None
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref484">
#          </a>
#          <a id="ORA-01051">
#          </a>
#          ORA-01051: deferred rpc buffer format invalid
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The deferred rpc data in sys.def$_call is corrupted.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Contact your customer support representive.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref485">
#          </a>
#          <a id="ORA-01052">
#          </a>
#          ORA-01052: required destination LOG_ARCHIVE_DUPLEX_DEST is not specified
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
# ...
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Consult your manual.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref796">
#          </a>
#          <a id="ORA-01482">
#          </a>
#          ORA-01482: unsupported character set
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The character set used to perform the operation, such as the CONVERT function, is not a supported character set.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Use one of the supported character sets.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref797">
#          </a>
#          <a id="ORA-01483">
#          </a>
#          ORA-01483: invalid length for DATE or NUMBER bind variable
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          A bind variable of type DATE or NUMBER is too long.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Consult your manual for the maximum allowable length.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref798">
#          </a>
#          <a id="ORA-01484">
#          </a>
#          ORA-01484: arrays can only be bound to PL/SQL statements
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          You tried to bind an array to a non-PL/SQL statement.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          None
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref799">
#          </a>
#          <a id="ORA-01485">
#          </a>
#          ORA-01485: compile bind length different from execute bind length
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          You bound a buffer of type DTYVCS (VARCHAR with the two byte length in front) and at execute time the length in the first two bytes is more than the maximum buffer length (given in the bind call). The number of elements in the array and the current number of elements in the array cannot be more than the maximum size of the array.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          None
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref800">
#          </a>
#          <a id="ORA-01486">
#          </a>
#          ORA-01486: size of array element is too large
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          You tried to bind a data value which was either too large for the datatype (for example, NUMBER) or was greater than 4000 bytes (for example, VARCHAR or LONG).
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          None
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref801">
#          </a>
#          <a id="ORA-01487">
#          </a>
#          ORA-01487: packed decimal number too large for supplied buffer
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An impossible request for decimal to oracle number conversion was made
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          This conversion cannot be performed
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref802">
#          </a>
#          <a id="ORA-01488">
#          </a>
#          ORA-01488: invalid nibble or byte in the input data
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          An impossible request for decimal to oracle number conversion was made
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          This conversion cannot be performed
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref803">
#          </a>
#          <a id="ORA-01489">
#          </a>
#          ORA-01489: result of string concatenation is too long
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          String concatenation result is more than the maximum size.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Make sure that the result is less than the maximum size.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref804">
#          </a>
#          <a id="ORA-01490">
#          </a>
#          ORA-01490: invalid ANALYZE command
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          Incorrect syntax specified
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Retry the command
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref805">
#          </a>
#          <a id="ORA-01491">
#          </a>
#          ORA-01491: CASCADE option not valid
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The CASCADE option is only valid for tables or clusters.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Do not specify CASCADE
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref806">
#          </a>
#          <a id="ORA-01492">
#          </a>
#          ORA-01492: LIST option not valid
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The LIST option is only valid for tables or clusters.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Do not specify LIST
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref807">
#          </a>
#          <a id="ORA-01493">
#          </a>
#          ORA-01493: invalid SAMPLE size specified
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The specified SAMPLE size is out of range
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Specify a value within the proper range.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref808">
#          </a>
#          <a id="ORA-01494">
#          </a>
#          ORA-01494: invalid SIZE specified
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The specified histogram SIZE value was out of range.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Specify a value within the proper range.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref809">
#          </a>
#          <a id="ORA-01495">
#          </a>
#          ORA-01495: specified chain row table not found
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The specified table either does not exist or user does not have the proper privleges.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Specify the correct table to use.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref810">
#          </a>
#          <a id="ORA-01496">
#          </a>
#          ORA-01496: specified chain row table form incorrect
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The specified table does not have the proper field definitions.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Specify the correct table to use.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#      <div class="msgentry">
#       <dl>
#        <dt>
#         <span class="msg">
#          <a id="sthref811">
#          </a>
#          <a id="ORA-01497">
#          </a>
#          ORA-01497: illegal option for ANALYZE CLUSTER
#         </span>
#         <!-- class="msg" -->
#        </dt>
#        <dd>
#         <div class="msgexplan">
#          <span class="msgexplankw">
#           Cause:
#          </span>
#          The FOR COLUMNS &lt;column-list&gt; clause may not be used with ANALYZE CLUSTER.
#         </div>
#         <!-- class="msgexplan" -->
#        </dd>
#        <dd>
#         <div class="msgaction">
#          <span class="msgactionkw">
#           Action:
#          </span>
#          Retry with a legal syntax.
#         </div>
#         <!-- class="msgaction" -->
#        </dd>
#       </dl>
#      </div>
#      <!-- class="msgentry" -->
#     </div>
#     <!-- class="msgset" -->
#    </div>
#    <!-- class="ind" -->
#    <!-- Start Footer -->
#   </div>
#   <!-- add extra wrapper close div-->
#   <footer>
#    <!--
# <hr />
# <table class="cellalignment980">
# <tr>
# <td class="cellalignment987">
# <table class="cellalignment985">
# <tr>
# <td class="cellalignment984"><a href="e0.htm"><img width="24" height="24" src="../../dcommon/gifs/leftnav.gif" alt="Go to previous page" /><br />
# <span class="icon">Previous</span></a></td>
# <td class="cellalignment984"><a href="e1500.htm"><img width="24" height="24" src="../../dcommon/gifs/rightnav.gif" alt="Go to next page" /><br />
# <span class="icon">Next</span></a></td>
# </tr>
# </table>
# </td>
# <td class="cellalignment-copyrightlogo"><img width="144" height="18" src="../../dcommon/gifs/oracle.gif" alt="Oracle" /><br />
# Copyright&nbsp;&copy;&nbsp;2008,&nbsp;Oracle.&nbsp;All&nbsp;rights&nbsp;reserved.<br />
# <a href="../../dcommon/html/cpyr.htm">Legal Notices</a></td>
# <td class="cellalignment989">
# <table class="cellalignment983">
# <tr>
# <td class="cellalignment984"><a href="../../index.htm"><img width="24" height="24" src="../../dcommon/gifs/doclib.gif" alt="Go to Documentation Home" /><br />
# <span class="icon">Home</span></a></td>
# <td class="cellalignment984"><a href="../../nav/portal_booklist.htm"><img width="24" height="24" src="../../dcommon/gifs/booklist.gif" alt="Go to Book List" /><br />
# <span class="icon">Book List</span></a></td>
# <td class="cellalignment984"><a href="toc.htm"><img width="24" height="24" src="../../dcommon/gifs/toc.gif" alt="Go to Table of Contents" /><br />
# <span class="icon">Contents</span></a></td>
# <td class="cellalignment984"><a href="index.htm"><img width="24" height="24" src="../../dcommon/gifs/index.gif" alt="Go to Index" /><br />
# <span class="icon">Index</span></a></td>
# <td class="cellalignment984"><a href="../../nav/mindx.htm"><img width="24" height="24" src="../../dcommon/gifs/masterix.gif" alt="Go to Master Index" /><br />
# <span class="icon">Master Index</span></a></td>
# <td class="cellalignment984"><a href="../../dcommon/html/feedback.htm"><img width="24" height="24" src="../../dcommon/gifs/feedbck2.gif" alt="Go to Feedback page" /><br />
# <span class="icon">Contact Us</span></a></td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# -->
#   </footer>
#   <noscript>
#    <p>
#     Scripting on this page enhances content navigation, but does not change the content in any way.
#    </p>
#   </noscript>
#  </body>
# </html>

# %%
soup.div
# Out:
# <div class="row" id="CONTENT">
# <div class="IND large-9 medium-8 columns">
# <a id="BEGIN" name="BEGIN"></a>
# <span id="PAGE" style="display:none;">6/86</span> <!-- End Header --><a id="sthref438"></a>
# <h1 class="chapter"><span class="secnum">3</span> ORA-00910 to ORA-01497</h1>
# <div class="msgset">
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref439"></a><a id="ORA-00910"></a>ORA-00910: specified length too long for its datatype</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> for datatypes CHAR and RAW, the length specified was &gt; 2000; otherwise, the length specified was &gt; 4000.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> use a shorter length or switch to a datatype permitting a longer length such as a VARCHAR2, LONG CHAR, or LONG RAW</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref440"></a><a id="ORA-00911"></a>ORA-00911: invalid character</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> identifiers may not start with any ASCII character other than letters and numbers. $#_ are also allowed after the first character. Identifiers enclosed by doublequotes may contain any character other than a doublequote. Alternative quotes (q'#...#') cannot use spaces, tabs, or carriage returns as delimiters. For all other contexts, consult the SQL Language Reference Manual.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref441"></a><a id="ORA-00912"></a>ORA-00912: input parameter too long</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> one of your input strings was too long</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> shorten the input parameter length</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref442"></a><a id="ORA-00953"></a>ORA-00953: missing or invalid index name</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An index name of the form [ &lt;identifier&gt; . ] &lt;identifier&gt; is expected but not present. If OIDINDEX clause, index name must be &lt;identifier&gt;</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Enter an appropriate index name.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref443"></a><a id="ORA-00956"></a>ORA-00956: missing or invalid auditing option</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> AUDIT or NOAUDIT statement contains an invalid auditing option.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Use a valid option.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref444"></a><a id="ORA-00960"></a>ORA-00960: ambiguous column naming in select list</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> A column name in the order-by list matches more than one select list columns.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Remove duplicate column naming in select list.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref445"></a><a id="ORA-00962"></a>ORA-00962: too many group-by / order-by expressions</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The group-by or order-by column list contain more than 1000 expressions.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Use 1000 or less expressions in the group-by or order-by list.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref446"></a><a id="ORA-00964"></a>ORA-00964: table name not in FROM list</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The table name referred in the select list is not specified in the from list.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure the name is correctly specified and matches one of the names in the from list.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref447"></a><a id="ORA-00965"></a>ORA-00965: column aliases not allowed for '*'</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The statement is trying to alias the * expression in the select list which is not legal.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Remove the alias.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref448"></a><a id="ORA-00972"></a>ORA-00972: identifier is too long</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An identifier with more than 30 characters was specified.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Specify at most 30 characters.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref449"></a><a id="ORA-00976"></a>ORA-00976: LEVEL, PRIOR, or ROWNUM not allowed here</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> LEVEL, PRIOR, or ROWNUM is being specified at illegal location.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Remove LEVEL, PRIOR, or ROWNUM.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref450"></a><a id="ORA-00977"></a>ORA-00977: duplicate auditing option</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> AUDIT or NOAUDIT statement specifies an option more than once</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Either use ALL with no other auditing options or make sure no option is listed more than once.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref451"></a><a id="ORA-00980"></a>ORA-00980: synonym translation is no longer valid</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> A synonym did not translate to a legal target object. This could happen for one of the following reasons:
# <p>1. The target schema does not exist.</p>
# <p>2. The target object does not exist.</p>
# <p>3. The synonym specifies an incorrect database link.</p>
# <p>4. The synonym is not versioned but specifies a versioned target object.</p>
# </div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Change the synonym definition so that the synonym points at a legal target object.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref452"></a><a id="ORA-00981"></a>ORA-00981: cannot mix table and system auditing options</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Table and system-wide auditing options were specified in the same AUDIT or NOAUDIT statement.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> You must issue table and system options in separate statements.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref453"></a><a id="ORA-00983"></a>ORA-00983: cannot audit or noaudit SYS user actions</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to AUDIT or NOAUDIT SYS user actions.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Execute the statement again with a valid user.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref454"></a><a id="ORA-00991"></a>ORA-00991: only MAC privileges may be granted to procedures</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Object privileges or non-MAC system privileges were granted to the procedure.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Only grant MAC privileges using the PROCEDURE clause.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref455"></a><a id="ORA-01002"></a>ORA-01002: fetch out of sequence</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> This error means that a fetch has been attempted from a cursor which is no longer valid. Note that a PL/SQL cursor loop implicitly does fetches, and thus may also cause this error. There are a number of possible causes for this error, including: 1) Fetching from a cursor after the last row has been retrieved and the ORA-1403 error returned. 2) If the cursor has been opened with the FOR UPDATE clause, fetching after a COMMIT has been issued will return the error. 3) Rebinding any placeholders in the SQL statement, then issuing a fetch before reexecuting the statement.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> 1) Do not issue a fetch statement after the last row has been retrieved - there are no more rows to fetch. 2) Do not issue a COMMIT inside a fetch loop for a cursor that has been opened FOR UPDATE. 3) Reexecute the statement after rebinding, then attempt to fetch again.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref456"></a><a id="ORA-01010"></a>ORA-01010: invalid OCI operation</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> One of the following: 1) You attempted an invalid OCI operation. 2) You are using an Oracle client application linked with version 7.1 (or higher) libraries, the environment variable ORA_ENCRYPT_LOGIN is set to TRUE, and you attempted to connect to a version 7.0 (or lower) Oracle Server. 3) You are connected to a version 7.1 (or higher) Oracle Server, the initialization parameter DBLINK_ENCRYPT_LOGIN is set to TRUE, and you attempted to use a database link pointing to a version 7.0 (or lower) Oracle Server. 4) You are connected to a version 9.0.2(or higher) Oracle Server and you attempted to use a database link pointing to a version 9.0.1(or lower) Oracle Server for distributed autonomous transaction.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> For the above causes: 1) Do not use the invalid OCI operation. 2) If you do not wish to use encrypted connect passwords in your distributed database, set ORA_ENCRYPT_LOGIN to FALSE. If you wish to use encrypted connect passwords, you must upgrade all Oracle Servers to version 7.1 (or higher). 3) If you do not wish to use encrypted database links in your distributed database, set DBLINK_ENCRYPT_LOGIN to FALSE. If you wish to use encrypted database links, you must upgrade all Oracle Servers to version 7.1 (or higher). 4) Do not attempt distributed autonomous transaction on version 9.0.1(or lower) Oracle Server.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref457"></a><a id="ORA-01016"></a>ORA-01016: This function can be called only after a fetch</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Cursor in an invalid state.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the oci/upi function is called after fetch.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref458"></a><a id="ORA-01019"></a>ORA-01019: unable to allocate memory in the user side</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The user side memory allocator returned error.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Increase the processes heap size or switch to the old set of calls.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref459"></a><a id="ORA-01022"></a>ORA-01022: database operation not supported in this configuration</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The attempted database operation does not conform to the user programming interface (UPI) for the two communicating ORACLE servers.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> You may need to upgrade one or more of your ORACLE servers or re-link your user side application with new libraries. Report the problem to Worldwide Customer Support.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref460"></a><a id="ORA-01023"></a>ORA-01023: Cursor context not found (Invalid cursor number)</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The cursor number is not a valid open cursor.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the cursor is open.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref461"></a><a id="ORA-01025"></a>ORA-01025: UPI parameter out of range</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An integer parameter to a upi function is out of range.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> This usually indicates an error in a tool built on top of the oracle dbms. Report the error to your customer support representative.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref462"></a><a id="ORA-01026"></a>ORA-01026: multiple buffers of size &gt; 4000 in the bind list</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> More than one long buffer in the bind list.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Change the buffer size to be less than 4000 for the bind variable bound to a normal column.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref463"></a><a id="ORA-01027"></a>ORA-01027: bind variables not allowed for data definition operations</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to use a bind variable in a SQL data definition operation.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Such bind variables are not allowed.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref464"></a><a id="ORA-01028"></a>ORA-01028: internal two task error</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Received send long message but don't have the cursor context.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Report as a bug.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref465"></a><a id="ORA-01029"></a>ORA-01029: internal two task error</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Received a request to send the long again when there is no long</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Report as a bug</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref466"></a><a id="ORA-01030"></a>ORA-01030: SELECT ... INTO variable does not exist</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The SELECT... INTO specified in the bind call does not correspond to a variable in the SQL statement.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> If it is not possible to correct the statement, call customer support.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref467"></a><a id="ORA-01031"></a>ORA-01031: insufficient privileges</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to change the current username or password without the appropriate privilege. This error also occurs if attempting to install a database without the necessary operating system privileges. When Trusted Oracle is configure in DBMS MAC, this error may occur if the user was granted the necessary privilege at a higher label than the current login.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Ask the database administrator to perform the operation or grant the required privileges. For Trusted Oracle users getting this error although granted the the appropriate privilege at a higher label, ask the database administrator to regrant the privilege at the appropriate label.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref468"></a><a id="ORA-01032"></a>ORA-01032: no such userid</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> This is an internal error message related to Export/Import.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Contact customer support.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref469"></a><a id="ORA-01033"></a>ORA-01033: ORACLE initialization or shutdown in progress</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to log on while Oracle is being started up or shutdown.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Wait a few minutes. Then retry the operation.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref470"></a><a id="ORA-01034"></a>ORA-01034: ORACLE not available</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Oracle was not started up. Possible causes include the following:
# <p>- The SGA requires more space than was allocated for it.</p>
# <p>- The operating-system variable pointing to the instance is improperly defined.</p>
# </div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Refer to accompanying messages for possible causes and correct the problem mentioned in the other messages. If Oracle has been initialized, then on some operating systems, verify that Oracle was linked correctly. See the platform specific Oracle documentation.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref471"></a><a id="ORA-01035"></a>ORA-01035: ORACLE only available to users with RESTRICTED SESSION privilege</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Logins are disallowed because an instance started in restricted mode. Only users with RESTRICTED SESSION system privilege can log on.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Request that Oracle be restarted without the restricted option or obtain the RESTRICTED SESSION system privilege.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref472"></a><a id="ORA-01036"></a>ORA-01036: illegal variable name/number</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Unable to find bind context on user side</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the variable being bound is in the sql statement.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref473"></a><a id="ORA-01037"></a>ORA-01037: maximum cursor memory exceeded</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempting to process a complex sql statement which consumed all available memory of the cursor.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Simplify the complex sql statement.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref474"></a><a id="ORA-01038"></a>ORA-01038: cannot write database file version <span class="italic">string</span> with ORACLE version <span class="italic">string</span></span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempting to write datafile headers in an old format. The new format can not be used until after the database has been verified as being compatible with this software version.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Open the database to advance to the new file formats, then repeat the operation. If the operation is required before the database can be opened, then use the previous software release to do the operation.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref475"></a><a id="ORA-01039"></a>ORA-01039: insufficient privileges on underlying objects of the view</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempting to explain plan on other people's view without the necessary privileges on the underlying objects of the view.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Get necessary privileges or do not perform the offending operation.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref476"></a><a id="ORA-01040"></a>ORA-01040: invalid character in password; logon denied</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> There are multibyte characters in the password or some characters in the password are not in US7ASCII range.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Resubmit password with valid characters.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref477"></a><a id="ORA-01041"></a>ORA-01041: internal error. hostdef extension doesn't exist</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Pointer to hstdef extension in hstdef is null.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Report as a bug</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref478"></a><a id="ORA-01042"></a>ORA-01042: detaching a session with open cursors not allowed</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to detach a seesio n which had open cursors.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Close all the cursors before detaching the session.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref479"></a><a id="ORA-01043"></a>ORA-01043: user side memory corruption [<span class="italic">string</span>], [<span class="italic">string</span>], [<span class="italic">string</span>], [<span class="italic">string</span>]</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The application code corrupted some of the usr memory used by oracle</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the application code is not overwriting memory.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref480"></a><a id="ORA-01044"></a>ORA-01044: size <span class="italic">string</span> of buffer bound to variable exceeds maximum <span class="italic">string</span></span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to bind a buffer whose total size would exceed the maximum size allowed. Total array size for arrays is calculated as: (element_size)*(number of elements)</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Reduce buffer size.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref481"></a><a id="ORA-01045"></a>ORA-01045: user <span class="italic">string</span> lacks CREATE SESSION privilege; logon denied</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> A connect was attempted to a userid which does not have create session privilege.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Grant the user CREATE SESSION privilege.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref482"></a><a id="ORA-01048"></a>ORA-01048: Couldn't find the specified procedure in the given context</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The procedure user specified in deferred RPC doesn't exist.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Check to make sure that the procedure exists and is visible to the replication process.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref483"></a><a id="ORA-01049"></a>ORA-01049: Bind by name is not spupportted in streamed RPC</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> A newer version of server is talking with this version requesting an operation not supported in this version.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref484"></a><a id="ORA-01051"></a>ORA-01051: deferred rpc buffer format invalid</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The deferred rpc data in sys.def$_call is corrupted.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Contact your customer support representive.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref485"></a><a id="ORA-01052"></a>ORA-01052: required destination LOG_ARCHIVE_DUPLEX_DEST is not specified</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> A valid destination for parameter LOG_ARCHIVE_DUPLEX_DEST was not specified when parameter LOG_ARCHIVE_MIN_SUCCEED_DEST was set to two.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Either specify a value for parameter LOG_ARCHIVE_DUPLEX_DEST, or reduce the value for parameter LOG_ARCHIVE_MIN_SUCCEED_DEST to one.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref486"></a><a id="ORA-01055"></a>ORA-01055: Object datatypes not supported for bind or define in this mode</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Bind or Define used for objects with an invalid mode</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Change the mode.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref487"></a><a id="ORA-01058"></a>ORA-01058: internal New Upi interface error</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempt to delete non existant hstdef extension.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Report as a bug.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref488"></a><a id="ORA-01059"></a>ORA-01059: parse expected before a bind or execute</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The client application attempted to bind a variable or execute a cursor opened in a PL/SQL block before the statement was parsed.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Ensure the statement is parsed before a bind or execute.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref489"></a><a id="ORA-01060"></a>ORA-01060: array binds or executes not allowed</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The client application attempted to bind an array of cursors or attempted to repeatedly execute against a PL/SQL block with a bind variable of type cursor.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Bind a single cursor or execute the PL/SQL block once.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref490"></a><a id="ORA-01061"></a>ORA-01061: cannot start up a V8 server using a V7 client application</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> You are using an Oracle client application linked with version 7 (or lower) libraries and you attempted to start up a V8 (or higher) server.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Use a client application linked with V8 (or higher) libraries.60</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref491"></a><a id="ORA-01062"></a>ORA-01062: unable to allocate memory for define buffer</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Exceeded the maximum buffer size for current plaform</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Use piecewise fetch with a smaller buffer size</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref492"></a><a id="ORA-01070"></a>ORA-01070: Using an old version of Oracle for the server</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Using pre 7.0.10.1 version of oracle for server</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Upgrade server to post 7.0.10.1 version</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref493"></a><a id="ORA-01071"></a>ORA-01071: cannot perform operation without starting up ORACLE</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref494"></a><a id="ORA-01072"></a>ORA-01072: cannot stop ORACLE; ORACLE not running</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref495"></a><a id="ORA-01073"></a>ORA-01073: fatal connection error: unrecognized call type</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An illegal internal operation was attempted.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Contact your customer support representative.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref496"></a><a id="ORA-01074"></a>ORA-01074: cannot shut down ORACLE; inside a login session - log off first</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref497"></a><a id="ORA-01075"></a>ORA-01075: you are currently logged on</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempt to login while logged in.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref498"></a><a id="ORA-01076"></a>ORA-01076: multiple logons per process not yet supported</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref499"></a><a id="ORA-01077"></a>ORA-01077: background process initialization failure</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Failure during initialization of ORACLE background processes.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Further diagnostic information should be in the error stack or in the trace file.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref500"></a><a id="ORA-01078"></a>ORA-01078: failure in processing system parameters</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Failure during processing of INIT.ORA parameters during system startup.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Further diagnostic information should be in the error stack.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref501"></a><a id="ORA-01079"></a>ORA-01079: ORACLE database was not properly created, operation aborted</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> There was an error when the database or control file was created.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> s to recreate the database or a new control file.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref502"></a><a id="ORA-01080"></a>ORA-01080: error in shutting down ORACLE</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Failure during system shutdown.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Further diagnostic information should be in the error stack.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref503"></a><a id="ORA-01081"></a>ORA-01081: cannot start already-running ORACLE - shut it down first</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref504"></a><a id="ORA-01082"></a>ORA-01082: 'row_locking = always' requires the transaction processing option</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> "row_locking = always" is specified in INIT.ORA file. This feature is not supported by ORACLE without the transaction processing option.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Remove it from INIT.ORA file or set it to "default" or "intent".</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref505"></a><a id="ORA-01083"></a>ORA-01083: value of parameter "<span class="italic">string</span>" is inconsistent with that of other instances</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The value of the given parameter is required to be the same for all instances in the cluster database configuration. ROW_LOCKING and SERIALIZABLE are 2 examples.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Change the value of the parameter in INIT.ORA file to match that of other cluster database instances.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref506"></a><a id="ORA-01084"></a>ORA-01084: invalid argument in OCI call</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The failing OCI call contains an argument with an invalid value.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Use valid argument values. For more information, see the Programmer's Guide to the Oracle Call Interfaces and the appropriate programming language supplement.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref507"></a><a id="ORA-01085"></a>ORA-01085: preceding errors in deferred rpc to "<span class="italic">string</span>.<span class="italic">string</span>.<span class="italic">string</span>"</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Errors were encountered when the named procedure was executed as a deferred remoted procedure call.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Correct the cause of the preceding errors.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref508"></a><a id="ORA-01086"></a>ORA-01086: savepoint '<span class="italic">string</span>' never established</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Trying to roll back to a save point that was never established.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref509"></a><a id="ORA-01088"></a>ORA-01088: cannot shut down ORACLE while active processes exist</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Users are still logged into the instance.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Either wait for all users to logoff or use SHUTDOWN IMMEDIATE.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref510"></a><a id="ORA-01089"></a>ORA-01089: immediate shutdown in progress - no operations are permitted</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The SHUTDOWN IMMEDIATE command was used to shut down a running ORACLE instance, so your operations have been terminated.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Wait for the instance to be restarted, or contact your DBA.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref511"></a><a id="ORA-01090"></a>ORA-01090: shutdown in progress - connection is not permitted</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The SHUTDOWN command was used to shut down a running ORACLE instance, so you cannot connect to ORACLE.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Wait for the instance to be restarted, or contact your DBA.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref512"></a><a id="ORA-01091"></a>ORA-01091: failure during startup force</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Unable to destroy the old SGA.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Manually remove the old SGA and reissue the STARTUP command</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref513"></a><a id="ORA-01092"></a>ORA-01092: ORACLE instance terminated. Disconnection forced</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The instance this process was connected to was terminated abnormally, probably via a shutdown abort. This process was forced to disconnect from the instance.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Examine the alert log for more details. When the instance has been restarted, retry action.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref514"></a><a id="ORA-01093"></a>ORA-01093: ALTER DATABASE CLOSE only permitted with no sessions connected</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> There is at least one more session other than the current one logged into the instance. ALTER DATABASE CLOSE is not permitted.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Find the other sessions and log them out and resubmit the command</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref515"></a><a id="ORA-01095"></a>ORA-01095: DML statement processed zero rows</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> During a call to OTEX, an update, delete, or insert statement being executed processed zero rows. The execution of statements by OTEX was halted at this point.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref516"></a><a id="ORA-01096"></a>ORA-01096: program version (<span class="italic">string</span>) incompatible with instance (<span class="italic">string</span>)</span> <!-- class="msg" --></dt>
# <dd>
# ...
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref784"></a><a id="ORA-01438"></a>ORA-01438: value larger than specified precision allowed for this column</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> When inserting or updating records, a numeric value was entered that exceeded the precision defined for the column.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Enter a value that complies with the numeric column's precision, or use the MODIFY option with the ALTER TABLE command to expand the precision.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref785"></a><a id="ORA-01451"></a>ORA-01451: column to be modified to NULL cannot be modified to NULL</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> the column may already allow NULL values, the NOT NULL constraint is part of a primary key or check constraint.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> if a primary key or check constraint is enforcing the NOT NULL constraint, then drop that constraint.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref786"></a><a id="ORA-01453"></a>ORA-01453: SET TRANSACTION must be first statement of transaction</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> self-evident</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> commit (or rollback) transaction, and re-execute</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref787"></a><a id="ORA-01456"></a>ORA-01456: may not perform insert/delete/update operation inside a READ ONLY transaction</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> A non-DDL insert/delete/update or select for update operation was attempted</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> commit (or rollback) transaction, and re-execute</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref788"></a><a id="ORA-01463"></a>ORA-01463: cannot modify column datatype with current constraint(s)</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to modify the datatype of column which has referential constraints; or has check constraints which only allows changing the datatype from CHAR to VARCHAR or vise versa.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Remove the constraint(s) or do not perform the offending operation.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref789"></a><a id="ORA-01466"></a>ORA-01466: unable to read data - table definition has changed</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Query parsed after tbl (or index) change, and executed w/old snapshot</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> commit (or rollback) transaction, and re-execute</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref790"></a><a id="ORA-01469"></a>ORA-01469: PRIOR can only be followed by a column name</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempting to specify "PRIOR &lt;something&gt;" where &lt;something&gt; is not a column name.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Only a column name can follow PRIOR. Replace with a column name.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref791"></a><a id="ORA-01470"></a>ORA-01470: In-list iteration does not support mixed operators</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Constants of different types are specified in an in-list.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Use constants of same type for in-lists.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref792"></a><a id="ORA-01478"></a>ORA-01478: array bind may not include any LONG columns</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> User is performing an array bind with a bind variable whose maximum size is greater than 2000 bytes.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Such bind variables cannot participate in array binds. Use an ordinary bind operation instead.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref793"></a><a id="ORA-01479"></a>ORA-01479: last character in the buffer is not Null</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> A bind variable of type 97 does not contain null at the last position</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Make the last character null</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref794"></a><a id="ORA-01480"></a>ORA-01480: trailing null missing from STR bind value</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> A bind variable of type 5 (null-terminated string) does not contain the terminating null in its buffer.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Terminate the string with a null character</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref795"></a><a id="ORA-01481"></a>ORA-01481: invalid number format model</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The user is attempting to either convert a number to a string via TO_CHAR or a string to a number via TO_NUMBER and has supplied an invalid number format model parameter.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Consult your manual.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref796"></a><a id="ORA-01482"></a>ORA-01482: unsupported character set</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The character set used to perform the operation, such as the CONVERT function, is not a supported character set.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Use one of the supported character sets.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref797"></a><a id="ORA-01483"></a>ORA-01483: invalid length for DATE or NUMBER bind variable</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> A bind variable of type DATE or NUMBER is too long.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Consult your manual for the maximum allowable length.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref798"></a><a id="ORA-01484"></a>ORA-01484: arrays can only be bound to PL/SQL statements</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> You tried to bind an array to a non-PL/SQL statement.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref799"></a><a id="ORA-01485"></a>ORA-01485: compile bind length different from execute bind length</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> You bound a buffer of type DTYVCS (VARCHAR with the two byte length in front) and at execute time the length in the first two bytes is more than the maximum buffer length (given in the bind call). The number of elements in the array and the current number of elements in the array cannot be more than the maximum size of the array.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref800"></a><a id="ORA-01486"></a>ORA-01486: size of array element is too large</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> You tried to bind a data value which was either too large for the datatype (for example, NUMBER) or was greater than 4000 bytes (for example, VARCHAR or LONG).</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref801"></a><a id="ORA-01487"></a>ORA-01487: packed decimal number too large for supplied buffer</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An impossible request for decimal to oracle number conversion was made</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> This conversion cannot be performed</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref802"></a><a id="ORA-01488"></a>ORA-01488: invalid nibble or byte in the input data</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> An impossible request for decimal to oracle number conversion was made</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> This conversion cannot be performed</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref803"></a><a id="ORA-01489"></a>ORA-01489: result of string concatenation is too long</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> String concatenation result is more than the maximum size.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the result is less than the maximum size.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref804"></a><a id="ORA-01490"></a>ORA-01490: invalid ANALYZE command</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> Incorrect syntax specified</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Retry the command</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref805"></a><a id="ORA-01491"></a>ORA-01491: CASCADE option not valid</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The CASCADE option is only valid for tables or clusters.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Do not specify CASCADE</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref806"></a><a id="ORA-01492"></a>ORA-01492: LIST option not valid</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The LIST option is only valid for tables or clusters.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Do not specify LIST</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref807"></a><a id="ORA-01493"></a>ORA-01493: invalid SAMPLE size specified</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The specified SAMPLE size is out of range</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Specify a value within the proper range.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref808"></a><a id="ORA-01494"></a>ORA-01494: invalid SIZE specified</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The specified histogram SIZE value was out of range.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Specify a value within the proper range.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref809"></a><a id="ORA-01495"></a>ORA-01495: specified chain row table not found</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The specified table either does not exist or user does not have the proper privleges.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Specify the correct table to use.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref810"></a><a id="ORA-01496"></a>ORA-01496: specified chain row table form incorrect</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The specified table does not have the proper field definitions.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Specify the correct table to use.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" -->
# <div class="msgentry">
# <dl>
# <dt><span class="msg"><a id="sthref811"></a><a id="ORA-01497"></a>ORA-01497: illegal option for ANALYZE CLUSTER</span> <!-- class="msg" --></dt>
# <dd>
# <div class="msgexplan"><span class="msgexplankw">Cause:</span> The FOR COLUMNS &lt;column-list&gt; clause may not be used with ANALYZE CLUSTER.</div>
# <!-- class="msgexplan" --></dd>
# <dd>
# <div class="msgaction"><span class="msgactionkw">Action:</span> Retry with a legal syntax.</div>
# <!-- class="msgaction" --></dd>
# </dl>
# </div>
# <!-- class="msgentry" --></div>
# <!-- class="msgset" --></div>
# <!-- class="ind" -->
# <!-- Start Footer -->
# </div>

# %% [markdown]
# We need to extract `title`, `cause`, and `action` data from Oracle errors webpage, so from html code we can see that, this data is in tag `msgentries`. <br>
# So first step is to find all the data with class `msgentry`, then by iterating though we can get all the necessary information.

# %%
#%% Getting all div having class msgentry

msgentries = soup.find_all('div',class_ = "msgentry")
msgentries
# Out:
# [<div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref439"></a><a id="ORA-00910"></a>ORA-00910: specified length too long for its datatype</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> for datatypes CHAR and RAW, the length specified was &gt; 2000; otherwise, the length specified was &gt; 4000.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> use a shorter length or switch to a datatype permitting a longer length such as a VARCHAR2, LONG CHAR, or LONG RAW</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref440"></a><a id="ORA-00911"></a>ORA-00911: invalid character</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> identifiers may not start with any ASCII character other than letters and numbers. $#_ are also allowed after the first character. Identifiers enclosed by doublequotes may contain any character other than a doublequote. Alternative quotes (q'#...#') cannot use spaces, tabs, or carriage returns as delimiters. For all other contexts, consult the SQL Language Reference Manual.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref441"></a><a id="ORA-00912"></a>ORA-00912: input parameter too long</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> one of your input strings was too long</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> shorten the input parameter length</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref442"></a><a id="ORA-00953"></a>ORA-00953: missing or invalid index name</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An index name of the form [ &lt;identifier&gt; . ] &lt;identifier&gt; is expected but not present. If OIDINDEX clause, index name must be &lt;identifier&gt;</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Enter an appropriate index name.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref443"></a><a id="ORA-00956"></a>ORA-00956: missing or invalid auditing option</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> AUDIT or NOAUDIT statement contains an invalid auditing option.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Use a valid option.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref444"></a><a id="ORA-00960"></a>ORA-00960: ambiguous column naming in select list</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A column name in the order-by list matches more than one select list columns.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Remove duplicate column naming in select list.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref445"></a><a id="ORA-00962"></a>ORA-00962: too many group-by / order-by expressions</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The group-by or order-by column list contain more than 1000 expressions.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Use 1000 or less expressions in the group-by or order-by list.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref446"></a><a id="ORA-00964"></a>ORA-00964: table name not in FROM list</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The table name referred in the select list is not specified in the from list.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure the name is correctly specified and matches one of the names in the from list.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref447"></a><a id="ORA-00965"></a>ORA-00965: column aliases not allowed for '*'</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The statement is trying to alias the * expression in the select list which is not legal.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Remove the alias.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref448"></a><a id="ORA-00972"></a>ORA-00972: identifier is too long</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An identifier with more than 30 characters was specified.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Specify at most 30 characters.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref449"></a><a id="ORA-00976"></a>ORA-00976: LEVEL, PRIOR, or ROWNUM not allowed here</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> LEVEL, PRIOR, or ROWNUM is being specified at illegal location.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Remove LEVEL, PRIOR, or ROWNUM.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref450"></a><a id="ORA-00977"></a>ORA-00977: duplicate auditing option</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> AUDIT or NOAUDIT statement specifies an option more than once</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Either use ALL with no other auditing options or make sure no option is listed more than once.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref451"></a><a id="ORA-00980"></a>ORA-00980: synonym translation is no longer valid</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A synonym did not translate to a legal target object. This could happen for one of the following reasons:
#  <p>1. The target schema does not exist.</p>
#  <p>2. The target object does not exist.</p>
#  <p>3. The synonym specifies an incorrect database link.</p>
#  <p>4. The synonym is not versioned but specifies a versioned target object.</p>
#  </div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Change the synonym definition so that the synonym points at a legal target object.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref452"></a><a id="ORA-00981"></a>ORA-00981: cannot mix table and system auditing options</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Table and system-wide auditing options were specified in the same AUDIT or NOAUDIT statement.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> You must issue table and system options in separate statements.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref453"></a><a id="ORA-00983"></a>ORA-00983: cannot audit or noaudit SYS user actions</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to AUDIT or NOAUDIT SYS user actions.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Execute the statement again with a valid user.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref454"></a><a id="ORA-00991"></a>ORA-00991: only MAC privileges may be granted to procedures</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Object privileges or non-MAC system privileges were granted to the procedure.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Only grant MAC privileges using the PROCEDURE clause.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref455"></a><a id="ORA-01002"></a>ORA-01002: fetch out of sequence</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> This error means that a fetch has been attempted from a cursor which is no longer valid. Note that a PL/SQL cursor loop implicitly does fetches, and thus may also cause this error. There are a number of possible causes for this error, including: 1) Fetching from a cursor after the last row has been retrieved and the ORA-1403 error returned. 2) If the cursor has been opened with the FOR UPDATE clause, fetching after a COMMIT has been issued will return the error. 3) Rebinding any placeholders in the SQL statement, then issuing a fetch before reexecuting the statement.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> 1) Do not issue a fetch statement after the last row has been retrieved - there are no more rows to fetch. 2) Do not issue a COMMIT inside a fetch loop for a cursor that has been opened FOR UPDATE. 3) Reexecute the statement after rebinding, then attempt to fetch again.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref456"></a><a id="ORA-01010"></a>ORA-01010: invalid OCI operation</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> One of the following: 1) You attempted an invalid OCI operation. 2) You are using an Oracle client application linked with version 7.1 (or higher) libraries, the environment variable ORA_ENCRYPT_LOGIN is set to TRUE, and you attempted to connect to a version 7.0 (or lower) Oracle Server. 3) You are connected to a version 7.1 (or higher) Oracle Server, the initialization parameter DBLINK_ENCRYPT_LOGIN is set to TRUE, and you attempted to use a database link pointing to a version 7.0 (or lower) Oracle Server. 4) You are connected to a version 9.0.2(or higher) Oracle Server and you attempted to use a database link pointing to a version 9.0.1(or lower) Oracle Server for distributed autonomous transaction.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> For the above causes: 1) Do not use the invalid OCI operation. 2) If you do not wish to use encrypted connect passwords in your distributed database, set ORA_ENCRYPT_LOGIN to FALSE. If you wish to use encrypted connect passwords, you must upgrade all Oracle Servers to version 7.1 (or higher). 3) If you do not wish to use encrypted database links in your distributed database, set DBLINK_ENCRYPT_LOGIN to FALSE. If you wish to use encrypted database links, you must upgrade all Oracle Servers to version 7.1 (or higher). 4) Do not attempt distributed autonomous transaction on version 9.0.1(or lower) Oracle Server.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref457"></a><a id="ORA-01016"></a>ORA-01016: This function can be called only after a fetch</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Cursor in an invalid state.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the oci/upi function is called after fetch.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref458"></a><a id="ORA-01019"></a>ORA-01019: unable to allocate memory in the user side</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The user side memory allocator returned error.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Increase the processes heap size or switch to the old set of calls.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref459"></a><a id="ORA-01022"></a>ORA-01022: database operation not supported in this configuration</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The attempted database operation does not conform to the user programming interface (UPI) for the two communicating ORACLE servers.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> You may need to upgrade one or more of your ORACLE servers or re-link your user side application with new libraries. Report the problem to Worldwide Customer Support.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref460"></a><a id="ORA-01023"></a>ORA-01023: Cursor context not found (Invalid cursor number)</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The cursor number is not a valid open cursor.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the cursor is open.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref461"></a><a id="ORA-01025"></a>ORA-01025: UPI parameter out of range</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An integer parameter to a upi function is out of range.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> This usually indicates an error in a tool built on top of the oracle dbms. Report the error to your customer support representative.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref462"></a><a id="ORA-01026"></a>ORA-01026: multiple buffers of size &gt; 4000 in the bind list</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> More than one long buffer in the bind list.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Change the buffer size to be less than 4000 for the bind variable bound to a normal column.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref463"></a><a id="ORA-01027"></a>ORA-01027: bind variables not allowed for data definition operations</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to use a bind variable in a SQL data definition operation.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Such bind variables are not allowed.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref464"></a><a id="ORA-01028"></a>ORA-01028: internal two task error</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Received send long message but don't have the cursor context.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Report as a bug.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref465"></a><a id="ORA-01029"></a>ORA-01029: internal two task error</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Received a request to send the long again when there is no long</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Report as a bug</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref466"></a><a id="ORA-01030"></a>ORA-01030: SELECT ... INTO variable does not exist</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The SELECT... INTO specified in the bind call does not correspond to a variable in the SQL statement.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> If it is not possible to correct the statement, call customer support.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref467"></a><a id="ORA-01031"></a>ORA-01031: insufficient privileges</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to change the current username or password without the appropriate privilege. This error also occurs if attempting to install a database without the necessary operating system privileges. When Trusted Oracle is configure in DBMS MAC, this error may occur if the user was granted the necessary privilege at a higher label than the current login.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Ask the database administrator to perform the operation or grant the required privileges. For Trusted Oracle users getting this error although granted the the appropriate privilege at a higher label, ask the database administrator to regrant the privilege at the appropriate label.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref468"></a><a id="ORA-01032"></a>ORA-01032: no such userid</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> This is an internal error message related to Export/Import.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Contact customer support.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref469"></a><a id="ORA-01033"></a>ORA-01033: ORACLE initialization or shutdown in progress</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to log on while Oracle is being started up or shutdown.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Wait a few minutes. Then retry the operation.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref470"></a><a id="ORA-01034"></a>ORA-01034: ORACLE not available</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Oracle was not started up. Possible causes include the following:
#  <p>- The SGA requires more space than was allocated for it.</p>
#  <p>- The operating-system variable pointing to the instance is improperly defined.</p>
#  </div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Refer to accompanying messages for possible causes and correct the problem mentioned in the other messages. If Oracle has been initialized, then on some operating systems, verify that Oracle was linked correctly. See the platform specific Oracle documentation.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref471"></a><a id="ORA-01035"></a>ORA-01035: ORACLE only available to users with RESTRICTED SESSION privilege</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Logins are disallowed because an instance started in restricted mode. Only users with RESTRICTED SESSION system privilege can log on.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Request that Oracle be restarted without the restricted option or obtain the RESTRICTED SESSION system privilege.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref472"></a><a id="ORA-01036"></a>ORA-01036: illegal variable name/number</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Unable to find bind context on user side</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the variable being bound is in the sql statement.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref473"></a><a id="ORA-01037"></a>ORA-01037: maximum cursor memory exceeded</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempting to process a complex sql statement which consumed all available memory of the cursor.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Simplify the complex sql statement.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref474"></a><a id="ORA-01038"></a>ORA-01038: cannot write database file version <span class="italic">string</span> with ORACLE version <span class="italic">string</span></span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempting to write datafile headers in an old format. The new format can not be used until after the database has been verified as being compatible with this software version.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Open the database to advance to the new file formats, then repeat the operation. If the operation is required before the database can be opened, then use the previous software release to do the operation.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref475"></a><a id="ORA-01039"></a>ORA-01039: insufficient privileges on underlying objects of the view</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempting to explain plan on other people's view without the necessary privileges on the underlying objects of the view.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Get necessary privileges or do not perform the offending operation.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref476"></a><a id="ORA-01040"></a>ORA-01040: invalid character in password; logon denied</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> There are multibyte characters in the password or some characters in the password are not in US7ASCII range.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Resubmit password with valid characters.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref477"></a><a id="ORA-01041"></a>ORA-01041: internal error. hostdef extension doesn't exist</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Pointer to hstdef extension in hstdef is null.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Report as a bug</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref478"></a><a id="ORA-01042"></a>ORA-01042: detaching a session with open cursors not allowed</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to detach a seesio n which had open cursors.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Close all the cursors before detaching the session.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref479"></a><a id="ORA-01043"></a>ORA-01043: user side memory corruption [<span class="italic">string</span>], [<span class="italic">string</span>], [<span class="italic">string</span>], [<span class="italic">string</span>]</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The application code corrupted some of the usr memory used by oracle</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the application code is not overwriting memory.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref480"></a><a id="ORA-01044"></a>ORA-01044: size <span class="italic">string</span> of buffer bound to variable exceeds maximum <span class="italic">string</span></span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to bind a buffer whose total size would exceed the maximum size allowed. Total array size for arrays is calculated as: (element_size)*(number of elements)</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Reduce buffer size.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref481"></a><a id="ORA-01045"></a>ORA-01045: user <span class="italic">string</span> lacks CREATE SESSION privilege; logon denied</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A connect was attempted to a userid which does not have create session privilege.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Grant the user CREATE SESSION privilege.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref482"></a><a id="ORA-01048"></a>ORA-01048: Couldn't find the specified procedure in the given context</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The procedure user specified in deferred RPC doesn't exist.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Check to make sure that the procedure exists and is visible to the replication process.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref483"></a><a id="ORA-01049"></a>ORA-01049: Bind by name is not spupportted in streamed RPC</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A newer version of server is talking with this version requesting an operation not supported in this version.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref484"></a><a id="ORA-01051"></a>ORA-01051: deferred rpc buffer format invalid</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The deferred rpc data in sys.def$_call is corrupted.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Contact your customer support representive.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref485"></a><a id="ORA-01052"></a>ORA-01052: required destination LOG_ARCHIVE_DUPLEX_DEST is not specified</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A valid destination for parameter LOG_ARCHIVE_DUPLEX_DEST was not specified when parameter LOG_ARCHIVE_MIN_SUCCEED_DEST was set to two.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Either specify a value for parameter LOG_ARCHIVE_DUPLEX_DEST, or reduce the value for parameter LOG_ARCHIVE_MIN_SUCCEED_DEST to one.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref486"></a><a id="ORA-01055"></a>ORA-01055: Object datatypes not supported for bind or define in this mode</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Bind or Define used for objects with an invalid mode</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Change the mode.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref487"></a><a id="ORA-01058"></a>ORA-01058: internal New Upi interface error</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempt to delete non existant hstdef extension.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Report as a bug.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref488"></a><a id="ORA-01059"></a>ORA-01059: parse expected before a bind or execute</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The client application attempted to bind a variable or execute a cursor opened in a PL/SQL block before the statement was parsed.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Ensure the statement is parsed before a bind or execute.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref489"></a><a id="ORA-01060"></a>ORA-01060: array binds or executes not allowed</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The client application attempted to bind an array of cursors or attempted to repeatedly execute against a PL/SQL block with a bind variable of type cursor.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Bind a single cursor or execute the PL/SQL block once.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref490"></a><a id="ORA-01061"></a>ORA-01061: cannot start up a V8 server using a V7 client application</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> You are using an Oracle client application linked with version 7 (or lower) libraries and you attempted to start up a V8 (or higher) server.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Use a client application linked with V8 (or higher) libraries.60</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref491"></a><a id="ORA-01062"></a>ORA-01062: unable to allocate memory for define buffer</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Exceeded the maximum buffer size for current plaform</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Use piecewise fetch with a smaller buffer size</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref492"></a><a id="ORA-01070"></a>ORA-01070: Using an old version of Oracle for the server</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Using pre 7.0.10.1 version of oracle for server</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Upgrade server to post 7.0.10.1 version</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref493"></a><a id="ORA-01071"></a>ORA-01071: cannot perform operation without starting up ORACLE</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref494"></a><a id="ORA-01072"></a>ORA-01072: cannot stop ORACLE; ORACLE not running</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref495"></a><a id="ORA-01073"></a>ORA-01073: fatal connection error: unrecognized call type</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An illegal internal operation was attempted.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Contact your customer support representative.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref496"></a><a id="ORA-01074"></a>ORA-01074: cannot shut down ORACLE; inside a login session - log off first</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref497"></a><a id="ORA-01075"></a>ORA-01075: you are currently logged on</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempt to login while logged in.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref498"></a><a id="ORA-01076"></a>ORA-01076: multiple logons per process not yet supported</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref499"></a><a id="ORA-01077"></a>ORA-01077: background process initialization failure</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Failure during initialization of ORACLE background processes.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Further diagnostic information should be in the error stack or in the trace file.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref500"></a><a id="ORA-01078"></a>ORA-01078: failure in processing system parameters</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Failure during processing of INIT.ORA parameters during system startup.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Further diagnostic information should be in the error stack.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref501"></a><a id="ORA-01079"></a>ORA-01079: ORACLE database was not properly created, operation aborted</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> There was an error when the database or control file was created.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> s to recreate the database or a new control file.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref502"></a><a id="ORA-01080"></a>ORA-01080: error in shutting down ORACLE</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Failure during system shutdown.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Further diagnostic information should be in the error stack.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref503"></a><a id="ORA-01081"></a>ORA-01081: cannot start already-running ORACLE - shut it down first</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref504"></a><a id="ORA-01082"></a>ORA-01082: 'row_locking = always' requires the transaction processing option</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> "row_locking = always" is specified in INIT.ORA file. This feature is not supported by ORACLE without the transaction processing option.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Remove it from INIT.ORA file or set it to "default" or "intent".</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref505"></a><a id="ORA-01083"></a>ORA-01083: value of parameter "<span class="italic">string</span>" is inconsistent with that of other instances</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The value of the given parameter is required to be the same for all instances in the cluster database configuration. ROW_LOCKING and SERIALIZABLE are 2 examples.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Change the value of the parameter in INIT.ORA file to match that of other cluster database instances.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref506"></a><a id="ORA-01084"></a>ORA-01084: invalid argument in OCI call</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The failing OCI call contains an argument with an invalid value.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Use valid argument values. For more information, see the Programmer's Guide to the Oracle Call Interfaces and the appropriate programming language supplement.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref507"></a><a id="ORA-01085"></a>ORA-01085: preceding errors in deferred rpc to "<span class="italic">string</span>.<span class="italic">string</span>.<span class="italic">string</span>"</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Errors were encountered when the named procedure was executed as a deferred remoted procedure call.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Correct the cause of the preceding errors.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref508"></a><a id="ORA-01086"></a>ORA-01086: savepoint '<span class="italic">string</span>' never established</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Trying to roll back to a save point that was never established.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref509"></a><a id="ORA-01088"></a>ORA-01088: cannot shut down ORACLE while active processes exist</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Users are still logged into the instance.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Either wait for all users to logoff or use SHUTDOWN IMMEDIATE.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref510"></a><a id="ORA-01089"></a>ORA-01089: immediate shutdown in progress - no operations are permitted</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The SHUTDOWN IMMEDIATE command was used to shut down a running ORACLE instance, so your operations have been terminated.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Wait for the instance to be restarted, or contact your DBA.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref511"></a><a id="ORA-01090"></a>ORA-01090: shutdown in progress - connection is not permitted</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The SHUTDOWN command was used to shut down a running ORACLE instance, so you cannot connect to ORACLE.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Wait for the instance to be restarted, or contact your DBA.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref512"></a><a id="ORA-01091"></a>ORA-01091: failure during startup force</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Unable to destroy the old SGA.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Manually remove the old SGA and reissue the STARTUP command</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref513"></a><a id="ORA-01092"></a>ORA-01092: ORACLE instance terminated. Disconnection forced</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The instance this process was connected to was terminated abnormally, probably via a shutdown abort. This process was forced to disconnect from the instance.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Examine the alert log for more details. When the instance has been restarted, retry action.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref514"></a><a id="ORA-01093"></a>ORA-01093: ALTER DATABASE CLOSE only permitted with no sessions connected</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> There is at least one more session other than the current one logged into the instance. ALTER DATABASE CLOSE is not permitted.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Find the other sessions and log them out and resubmit the command</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref515"></a><a id="ORA-01095"></a>ORA-01095: DML statement processed zero rows</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> During a call to OTEX, an update, delete, or insert statement being executed processed zero rows. The execution of statements by OTEX was halted at this point.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref516"></a><a id="ORA-01096"></a>ORA-01096: program version (<span class="italic">string</span>) incompatible with instance (<span class="italic">string</span>)</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A program is trying to connect to an instance using a different version of code than the database was started with. This is not allowed.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Either relink the program with the same version as the database or restart the database using the old version of code.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref517"></a><a id="ORA-01097"></a>ORA-01097: cannot shutdown while in a transaction - commit or rollback first</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref518"></a><a id="ORA-01099"></a>ORA-01099: cannot mount database in SHARED mode if started in single process mode</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Obvious</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
# ...
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref783"></a><a id="ORA-01429"></a>ORA-01429: Index-Organized Table: no data segment to store overflow row-pieces</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> No overflow segment defined.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Add overflow segment.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref784"></a><a id="ORA-01438"></a>ORA-01438: value larger than specified precision allowed for this column</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> When inserting or updating records, a numeric value was entered that exceeded the precision defined for the column.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Enter a value that complies with the numeric column's precision, or use the MODIFY option with the ALTER TABLE command to expand the precision.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref785"></a><a id="ORA-01451"></a>ORA-01451: column to be modified to NULL cannot be modified to NULL</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> the column may already allow NULL values, the NOT NULL constraint is part of a primary key or check constraint.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> if a primary key or check constraint is enforcing the NOT NULL constraint, then drop that constraint.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref786"></a><a id="ORA-01453"></a>ORA-01453: SET TRANSACTION must be first statement of transaction</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> self-evident</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> commit (or rollback) transaction, and re-execute</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref787"></a><a id="ORA-01456"></a>ORA-01456: may not perform insert/delete/update operation inside a READ ONLY transaction</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A non-DDL insert/delete/update or select for update operation was attempted</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> commit (or rollback) transaction, and re-execute</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref788"></a><a id="ORA-01463"></a>ORA-01463: cannot modify column datatype with current constraint(s)</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An attempt was made to modify the datatype of column which has referential constraints; or has check constraints which only allows changing the datatype from CHAR to VARCHAR or vise versa.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Remove the constraint(s) or do not perform the offending operation.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref789"></a><a id="ORA-01466"></a>ORA-01466: unable to read data - table definition has changed</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Query parsed after tbl (or index) change, and executed w/old snapshot</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> commit (or rollback) transaction, and re-execute</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref790"></a><a id="ORA-01469"></a>ORA-01469: PRIOR can only be followed by a column name</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Attempting to specify "PRIOR &lt;something&gt;" where &lt;something&gt; is not a column name.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Only a column name can follow PRIOR. Replace with a column name.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref791"></a><a id="ORA-01470"></a>ORA-01470: In-list iteration does not support mixed operators</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Constants of different types are specified in an in-list.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Use constants of same type for in-lists.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref792"></a><a id="ORA-01478"></a>ORA-01478: array bind may not include any LONG columns</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> User is performing an array bind with a bind variable whose maximum size is greater than 2000 bytes.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Such bind variables cannot participate in array binds. Use an ordinary bind operation instead.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref793"></a><a id="ORA-01479"></a>ORA-01479: last character in the buffer is not Null</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A bind variable of type 97 does not contain null at the last position</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Make the last character null</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref794"></a><a id="ORA-01480"></a>ORA-01480: trailing null missing from STR bind value</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A bind variable of type 5 (null-terminated string) does not contain the terminating null in its buffer.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Terminate the string with a null character</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref795"></a><a id="ORA-01481"></a>ORA-01481: invalid number format model</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The user is attempting to either convert a number to a string via TO_CHAR or a string to a number via TO_NUMBER and has supplied an invalid number format model parameter.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Consult your manual.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref796"></a><a id="ORA-01482"></a>ORA-01482: unsupported character set</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The character set used to perform the operation, such as the CONVERT function, is not a supported character set.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Use one of the supported character sets.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref797"></a><a id="ORA-01483"></a>ORA-01483: invalid length for DATE or NUMBER bind variable</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> A bind variable of type DATE or NUMBER is too long.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Consult your manual for the maximum allowable length.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref798"></a><a id="ORA-01484"></a>ORA-01484: arrays can only be bound to PL/SQL statements</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> You tried to bind an array to a non-PL/SQL statement.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref799"></a><a id="ORA-01485"></a>ORA-01485: compile bind length different from execute bind length</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> You bound a buffer of type DTYVCS (VARCHAR with the two byte length in front) and at execute time the length in the first two bytes is more than the maximum buffer length (given in the bind call). The number of elements in the array and the current number of elements in the array cannot be more than the maximum size of the array.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref800"></a><a id="ORA-01486"></a>ORA-01486: size of array element is too large</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> You tried to bind a data value which was either too large for the datatype (for example, NUMBER) or was greater than 4000 bytes (for example, VARCHAR or LONG).</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> None</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref801"></a><a id="ORA-01487"></a>ORA-01487: packed decimal number too large for supplied buffer</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An impossible request for decimal to oracle number conversion was made</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> This conversion cannot be performed</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref802"></a><a id="ORA-01488"></a>ORA-01488: invalid nibble or byte in the input data</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> An impossible request for decimal to oracle number conversion was made</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> This conversion cannot be performed</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref803"></a><a id="ORA-01489"></a>ORA-01489: result of string concatenation is too long</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> String concatenation result is more than the maximum size.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Make sure that the result is less than the maximum size.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref804"></a><a id="ORA-01490"></a>ORA-01490: invalid ANALYZE command</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> Incorrect syntax specified</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Retry the command</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref805"></a><a id="ORA-01491"></a>ORA-01491: CASCADE option not valid</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The CASCADE option is only valid for tables or clusters.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Do not specify CASCADE</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref806"></a><a id="ORA-01492"></a>ORA-01492: LIST option not valid</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The LIST option is only valid for tables or clusters.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Do not specify LIST</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref807"></a><a id="ORA-01493"></a>ORA-01493: invalid SAMPLE size specified</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The specified SAMPLE size is out of range</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Specify a value within the proper range.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref808"></a><a id="ORA-01494"></a>ORA-01494: invalid SIZE specified</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The specified histogram SIZE value was out of range.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Specify a value within the proper range.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref809"></a><a id="ORA-01495"></a>ORA-01495: specified chain row table not found</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The specified table either does not exist or user does not have the proper privleges.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Specify the correct table to use.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref810"></a><a id="ORA-01496"></a>ORA-01496: specified chain row table form incorrect</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The specified table does not have the proper field definitions.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Specify the correct table to use.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>, <div class="msgentry">
#  <dl>
#  <dt><span class="msg"><a id="sthref811"></a><a id="ORA-01497"></a>ORA-01497: illegal option for ANALYZE CLUSTER</span> <!-- class="msg" --></dt>
#  <dd>
#  <div class="msgexplan"><span class="msgexplankw">Cause:</span> The FOR COLUMNS &lt;column-list&gt; clause may not be used with ANALYZE CLUSTER.</div>
#  <!-- class="msgexplan" --></dd>
#  <dd>
#  <div class="msgaction"><span class="msgactionkw">Action:</span> Retry with a legal syntax.</div>
#  <!-- class="msgaction" --></dd>
#  </dl>
#  </div>]

# %% [markdown]
# Let's see the code for one `msgentry`

# %%
#%% Getting Title , Action , Cause for one msgentry

one = msgentries[0]
Title = one.dl.dt.text
print("Title :  ",Title)

Cause = one.find("div",class_ = "msgexplan")
print("Cause :  ",Cause.text)

Action = one.find("div",class_ = "msgaction")
print("Action :  ",Action.text)
# Out:
# Title :   ORA-00910: specified length too long for its datatype
# Cause :   Cause: for datatypes CHAR and RAW, the length specified was > 2000; otherwise, the length specified was > 4000.
# Action :   Action: use a shorter length or switch to a datatype permitting a longer length such as a VARCHAR2, LONG CHAR, or LONG RAW

# %% [markdown]
# Now we can iterate through all the data to extract `title`, `cause,` and `action` for every oracle error available in webpage.

# %%
#%% Getting Title , Action , Cause for all msgentry

# for i in range(len(msgentries)):
#     msg = msgentries[i]
#     Title = msg.dl.dt.text
#     print("\n",Title)
    
#     Cause = msg.find("div",class_ = "msgexplan")
#     print(Cause.text)
    
#     Action = msg.find("div",class_ = "msgaction")
#     print(Action.text)
#     print("\n")

# %%
idx = []
title = []
cause = []
action = []

# %%
#%%
for i in range(len(msgentries)):
    msg = msgentries[i]
    idx.append(i)
    
    Title = msg.dl.dt.text
    title.append(Title)
    
    Cause = msg.find("div",class_ = "msgexplan")
    cause.append(Cause)
    
    Action = msg.find("div",class_ = "msgaction")
    action.append(Action)

# %%
#%% Storing saved lists in dataframe

errors = pd.DataFrame()
errors['index'] = idx
errors['title'] = title
errors['cause'] = cause
errors['action'] = action

# %%
print(errors.action)
# Out:
# 0      [[Action:],  use a shorter length or switch to...
# 1                                     [[Action:],  None]
# 2       [[Action:],  shorten the input parameter length]
# 3         [[Action:],  Enter an appropriate index name.]
# 4                      [[Action:],  Use a valid option.]
#                              ...
# 368    [[Action:],  Specify a value within the proper...
# 369    [[Action:],  Specify a value within the proper...
# 370      [[Action:],  Specify the correct table to use.]
# 371      [[Action:],  Specify the correct table to use.]
# 372             [[Action:],  Retry with a legal syntax.]
# Name: action, Length: 373, dtype: object

# %%
#%% Export to CSV
errors.to_csv("errors_373", header = True, index = False)
